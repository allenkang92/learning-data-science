# %% [markdown]
# 절댓값 : 값과 0 사이의 거리를 나타냄. 인공지능에서 0을 중심으로 한 값의 퍼짐 상태를 파악하기 위해서 사용되는 경우가 있음

# %%
import numpy as np

x = [-5, 5, -1.28, np.sqrt(5), -np.pi/2]
# 여러 값을 리스트에 저장한다
print(np.abs(x)) # 절댓값을 구한다
# Out:
# [5.         5.         1.28       2.23606798 1.57079633]

# %%
# 삼각함수의 절댓값

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi) # -pi부터 pi(라디안)까지
y_sin = np.abs(np.sin(x)) # sin() 함수의 절댓값을 취한다
y_cos = np.abs(np.cos(x)) # cos() 함수의 절댓값을 취한다

plt.scatter(x, y_sin, label="sin")
plt.scatter(x, y_cos, label="cos")
plt.legend()

plt.xlabel("x", size = 14)
plt.ylabel("y", size = 14)
plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-4, 4)
y = np.abs(x**2 - 4) # 이 2차 함수의 절댓값을 취한다

plt.scatter(x, y)

plt.xlabel("x", size = 14)
plt.ylabel("y", size = 14)
plt.grid()

plt.show()
